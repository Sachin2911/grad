# %%
import pandas as pd

# %%
df = pd.read_json("../Data/graduateProgrammes.json")

# %%
df.head()
# Out:
#                                             position  \
# 0             Investec: Tech Graduate Programme 2023
# 1  Nedbank: Quantitative Analyst Graduate Program...
# 2                       BBD: Graduate Programme 2023
# 3  Tiger Brands: Future Leaders Graduate Developm...
# 4  Sasria: Quality Assurance Graduate Programme 2023
#
#                                          description  \
# 0  Investec Sandton is looking for Tech Graduates...
# 1  ResponsibilitiesSeek opportunities to improve ...
# 2  BBD is an international software firm that sol...
# 3  The Tiger Brands Future Leaders Development Pr...
# 4  The graduates will assist the Quality Assuranc...
#
#                                            applyLink  \
# 0  https://careers.investec.co.za/jobs/vacancy/te...
# 1  https://jobs.nedbank.co.za/job/Johannesburg-Qu...
# 2  https://bbdsoftware.com/jobs/Apply/apply.html?...
# 3  https://hcxb.fa.em2.oraclecloud.com/hcmUI/Cand...
# ...

# %%
df.shape
# Out:
# (391, 7)

# %%
description_list = df["description"].tolist()

# %%
len(description_list)
# Out:
# 391

# %%
for ind,i in enumerate(description_list):
    prompt = "What are the benefits of applying to this job just give points with max 8 words per point and also give the type of industry the job is in, your answer should be in json format e.g.  benefits:[...], industry: ... : "
    newi = prompt + i
    description_list[ind] = newi

# %%
description_list[1]
# Out:
# 'What are the benefits of applying to this job just give points with max 8 words per point and also give the type of industry the job is in, your answer should be in json format e.g.  benefits:[...], industry: ... : ResponsibilitiesSeek opportunities to improve business processes; models and systems by identifying and recommending effective ways to operate and adding value to Nedbank.\nContribute to the Nedbank Quants Training Programme by pro-actively participating in programme committees/structures (E.g.,\xa0marketing committee, recruitment committee and social committee). This is called ‘programme involvement’. The objective of this participation is to enhance their personal and professional development whilst adding value to the Nedbank Quants Training Programme.\nEnsure business needs are met by engaging and assisting business through\xa0face-to-face\xa0interaction and attendance at forums and\xa0committees.\nAssist the business to address queries by extracting and analysing dat
# ...

# %%
import requests
def chatGPT(text):
    url = "https://api.openai.com/v1/completions"
    headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer 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",
    }
    data = { 
    "model": "text-davinci-003",
    "prompt": text,
    "max_tokens": 1000,
    "temperature": 1.0,
    }
    response = requests.post(url, headers=headers, json=data)
    output = response.json()

    return output

# %%
len(description_list[1])
# Out:
# 1685

# %%
benefitsls = []
industry = []
extracted = []

# %%
for i in description_list:
    info = chatGPT(i)
    info
    extracted.append(info)

# %%
len(extracted)
# Out:
# 391

# %%
extracted
# Out:
# [{'error': {'message': 'The server had an error while processing your request. Sorry about that!',
#    'type': 'server_error',
#    'param': None,
#    'code': None}},
#  {'id': 'cmpl-7H5SsO4WPFtqVBUjkwFDECKct646D',
#   'object': 'text_completion',
#   'created': 1684306938,
#   'model': 'text-davinci-003',
#   'choices': [{'text': '\n\nBenefits: Develop Professional Skills, Add Value to Organization, Continuous Learning, Analytical Thinking, Develop Professional Network, Compliance with Regulators, \nIndustry: Banking and Financial Services',
#     'index': 0,
#     'logprobs': None,
#     'finish_reason': 'stop'}],
#   'usage': {'prompt_tokens': 325,
#    'completion_tokens': 39,
#    'total_tokens': 364}},
#  {'id': 'cmpl-7H5Sxgr3MO8wFulzLXfg58K3Kob0K',
#   'object': 'text_completion',
#   'created': 1684306943,
#   'model': 'text-davinci-003',
# ...

# %%
extracted[0]
# Out:
# {'error': {'message': 'The server had an error while processing your request. Sorry about that!',
#   'type': 'server_error',
#   'param': None,
#   'code': None}}

# %%
if 'error' in extracted[0]:
    print("tRUE")
# Out:
# tRUE

# %%
import json

result = []

for item in extracted:
    if 'choices' in item:
        newit = item['choices'][0]['text'].lower()
        newit = newit.replace("\n","")
        newit = newit.replace("benefits","")
        newit = newit.replace("industry","")
        newit = newit.replace("{","")
        newit = newit.replace("}","")
        filtered_list = [item for item in newit if len(item) > 5]
        benefits = newit.split(':')
        print(benefits)
# Out:
# ['', ' develop professional skills, add value to organization, continuous learning, analytical thinking, develop professional network, compliance with regulators, ', ' banking and financial services']
# ['', ' ', ' real project experience, flat management structure, continuous learning, high academic average, engaged with technology, creative problem solving, ', ' software, education, financial services, gaming, insurance, telecoms, public sectors.']
# ['', '     ""', ' ["gain experience in workplace", "learn different functions of company", "visit different locations/stores", "discover best practices", "make presentations", "develop talent", "infuse talent into organization", "structured learning"],     ""', ' "wholesale & retail"']
# [', preferably a master in an industrial or analytical field.    ', ' [increase knowledge, innovative environment, develop skills, projects diversity],    ', ' operations/supply chain ']
# ...
